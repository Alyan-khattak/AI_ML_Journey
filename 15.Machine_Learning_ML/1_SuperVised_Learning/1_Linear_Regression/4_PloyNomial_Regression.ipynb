# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # Polynomial Regression
#
# Polynomial Regression is a regression technique used when the relationship between the input features and the target variable is **non-linear**.
#
# Although it produces a curved line, it is still considered a form of **Linear Regression** because the model remains linear in its parameters (coefficients).
#
# ---
#
# # Why Does Simple Linear Regression Fail?
#
# Simple Linear Regression assumes that the relationship between the feature and target is a straight line:
#
# $$
# \hat{y} = \theta_0 + \theta_1x
# $$
#
# Consider the following data:
#
# | X | y  |
# | - | -- |
# | 1 | 1  |
# | 2 | 4  |
# | 3 | 9  |
# | 4 | 16 |
# | 5 | 25 |
#
# The actual relationship is:
#
# $$
# y=x^2
# $$
#
# ---
#
# ## Best Fit Line
#
# Simple Linear Regression tries to fit:
#
# ```text id="71x6zr"
#         *
#       *
#     *
#   *
# *
# -------------------->
# ```
#
# A straight line cannot capture the curve properly.
#
# This results in:
#
# * High bias
# * Underfitting
# * Poor predictions
#
# ---
#
# ## Actual Relationship
#
# ```text id="20g3zl"
#             *
#          *
#       *
#    *
# *
# -------------------->
# ```
#
# The data follows a curve rather than a straight line.
#
# ---
#
# # Intuition
#
# Instead of fitting:
#
# $$
# y = \theta_0 + \theta_1x
# $$
#
# we create additional features:
#
# $$
# x^2,;x^3,;x^4,\dots
# $$
#
# and fit:
#
# $$
# \hat{y}
# =======
#
# \theta_0
# +
# \theta_1x
# +
# \theta_2x^2
# +
# \theta_3x^3
# +\dots
# $$
#
# This allows the model to learn curved relationships.
#
# ---
#
# # Simple Polynomial Regression
#
# Simple Polynomial Regression uses **one feature**.
#
# ## Formula
#
# ### Degree 2
#
# $$
# \hat{y}
# =======
#
# \theta_0
# +
# \theta_1x
# +
# \theta_2x^2
# $$
#
# ---
#
# ### Degree 3
#
# $$
# \hat{y}
# =======
#
# \theta_0
# +
# \theta_1x
# +
# \theta_2x^2
# +
# \theta_3x^3
# $$
#
# ---
#
# ## Example
#
# Suppose:
#
# | Study Hours | Marks |
# | ----------- | ----- |
# | 1           | 5     |
# | 2           | 15    |
# | 3           | 40    |
# | 4           | 80    |
# | 5           | 130   |
#
# The relationship is curved:
#
# ```text id="9qim5v"
#                *
#             *
#          *
#       *
#    *
# -------------------->
# ```
#
# A polynomial curve fits the data much better than a straight line.
#
# ---
#
# # Multiple Polynomial Regression
#
# Multiple Polynomial Regression uses multiple features and their polynomial terms.
#
# Suppose we have:
#
# * Area
# * Bedrooms
#
# The model becomes:
#
# $$
# \hat{y}
# =======
#
# \theta_0
# +
# \theta_1x_1
# +
# \theta_2x_2
# +
# \theta_3x_1^2
# +
# \theta_4x_2^2
# +
# \theta_5x_1x_2
# $$
#
# Where:
#
# | Symbol   | Meaning          |
# | -------- | ---------------- |
# | $x_1$    | First feature    |
# | $x_2$    | Second feature   |
# | $x_1x_2$ | Interaction term |
#
# ---
#
# # Polynomial Features
#
# Suppose:
#
# ```text id="m7dtxh"
# X = [2]
# ```
#
# Degree 3 creates:
#
# | Feature |
# | ------- |
# | 1       |
# | x       |
# | x²      |
# | x³      |
#
# Result:
#
# ```text id="3skabk"
# [1, 2, 4, 8]
# ```
#
# ---
#
# Suppose:
#
# ```text id="wvvjlwm"
# X = [2,3]
# ```
#
# Degree 2 creates:
#
# | Feature |
# | ------- |
# | 1       |
# | x₁      |
# | x₂      |
# | x₁²     |
# | x₁x₂    |
# | x₂²     |
#
# Result:
#
# ```text id="c9kkjk"
# [1,2,3,4,6,9]
# ```
#
# ---
#
# # Graph
#
# ## Simple Linear Regression
#
# ```text id="sn9vv8"
# y
# ↑
#
#       *
#     *
#   *
# *
# ------------------------→ x
# ```
#
# ---
#
# ## Polynomial Regression
#
# ```text id="y8lt2f"
# y
# ↑
#
#           *
#        *
#     *
#   *
# *
# ------------------------→ x
# ```
#
# The polynomial curve follows the actual pattern more closely.
#
# ---
#
# # Degree of Polynomial
#
# | Degree | Shape               |
# | ------ | ------------------- |
# | 1      | Straight line       |
# | 2      | Parabola            |
# | 3      | Cubic curve         |
# | 4+     | More complex curves |
#
# Examples:
#
# $$
# Degree\ 1:
# \quad
# y=a+bx
# $$
#
# $$
# Degree\ 2:
# \quad
# y=a+bx+cx^2
# $$
#
# $$
# Degree\ 3:
# \quad
# y=a+bx+cx^2+dx^3
# $$
#
# ---
#
# # Scikit-Learn Syntax
#
# ## Step 1: Create Polynomial Features
#
# ```python id="t2l2oq"
# from sklearn.preprocessing import PolynomialFeatures
#
# poly = PolynomialFeatures(degree=2)
# ```
#
# ---
#
# ## Step 2: Transform Features
#
# ```python id="4z5gnw"
# X_poly = poly.fit_transform(X)
# ```
#
# ---
#
# ## Step 3: Train Linear Regression
#
# ```python id="f95z5x"
# from sklearn.linear_model import LinearRegression
#
# model = LinearRegression()
#
# model.fit(X_poly, y)
# ```
#
# ---
#
# ## Step 4: Prediction
#
# ```python id="on81ft"
# y_pred = model.predict(X_poly)
# ```
#
# ---
#
# # Complete Example
#
# ```python id="j9wjuh"
# from sklearn.preprocessing import PolynomialFeatures
# from sklearn.linear_model import LinearRegression
#
# poly = PolynomialFeatures(degree=3)
#
# X_train_poly = poly.fit_transform(X_train)
# X_test_poly = poly.transform(X_test)
#
# model = LinearRegression()
#
# model.fit(X_train_poly, y_train)
#
# y_pred = model.predict(X_test_poly)
# ```
#
# ---
#
# # Advantages
#
# * Captures non-linear relationships.
# * More flexible than simple linear regression.
# * Easy to implement.
#
# ---
#
# # Disadvantages
#
# * Can easily overfit.
# * Higher degree increases complexity.
# * Harder to interpret.
#
# ---
#
# # When to Use Polynomial Regression
#
# Use polynomial regression when:
#
# * Scatter plots show a curved relationship.
# * Linear regression underfits.
# * The relationship between variables is non-linear.
#
# ---
#
# # One-Line Definition
#
# > Polynomial Regression extends Linear Regression by adding powers and combinations of features so that curved relationships can be modeled.

# %% [markdown]
# ____
# # Make Data Points Using Quadratic Equation
# ___

# %%
X = 6 * np.random.rand(100,1) - 3
Y = 0.5 * X**2 + 1.5*X + 2 + np.random.rand(100, 1)
# Quadratic Equation used: y = 0.5 X^2 + 1.5X + 2 +outliers
plt.scatter(X,Y, color = "Green")
plt.xlabel("X")
plt.ylabel("y")

# see the data has non  linear relation
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ____
# # Train Test Split
# ___

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.25, random_state=42)
# no need to standardize as both are in same unit

# %% [markdown]
# ___
# # 1st Check using Simple Linear Regression
#
# - see why it would give error
# ___

# %%
from sklearn.linear_model import LinearRegression

# %%
model_1 = LinearRegression()
model_1.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ___
# # Check Performance
# ___

# %%
from sklearn.metrics import r2_score

# %%
r2_score = r2_score(y_test, model_1.predict(X_test))

# %%
print(r2_score)

# less Accurate
# Out:
# 0.7687876720516641

# %%
plt.plot(X_train, model_1.predict(X_train), color = "red")
plt.scatter(X_train, y_train)
plt.xlabel("X")
plt.ylabel("Y")

# Best fit line has hight error
# Out:
# Text(0, 0.5, 'Y')

# %% [markdown]
# ___
# ___

# %% [markdown]
# ___
# # Polynomial Regession
# ___

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly  = PolynomialFeatures(degree=2, include_bias=True)

# degree = 2 means -->> h0X = Bo + b1X1 + B2X2^2
# include Bias means -->> multiple Bo with with 1

# %%
X_Train_poly = poly.fit_transform(X_train)  # degree 2 will be created for X-train
X_test_poly = poly.transform(X_test)

# %%
X_Train_poly
# Out:
# array([[ 1.00000000e+00,  9.16882302e-01,  8.40673156e-01],
#        [ 1.00000000e+00,  1.95216931e+00,  3.81096503e+00],
#        [ 1.00000000e+00, -1.95096611e+00,  3.80626875e+00],
#        [ 1.00000000e+00, -1.33584878e-01,  1.78449197e-02],
#        [ 1.00000000e+00, -2.51868210e+00,  6.34375953e+00],
#        [ 1.00000000e+00, -2.74426310e+00,  7.53097994e+00],
#        [ 1.00000000e+00,  2.12027476e+00,  4.49556508e+00],
#        [ 1.00000000e+00, -1.87432424e+00,  3.51309137e+00],
#        [ 1.00000000e+00, -2.19761331e+00,  4.82950426e+00],
#        [ 1.00000000e+00, -2.41066421e+00,  5.81130191e+00],
#        [ 1.00000000e+00,  2.55126179e+00,  6.50893674e+00],
#        [ 1.00000000e+00, -2.28840297e+00,  5.23678815e+00],
#        [ 1.00000000e+00,  1.89240639e+00,  3.58120196e+00],
#        [ 1.00000000e+00, -1.71907716e+00,  2.95522629e+00],
#        [ 1.00000000e+00,  1.94412143e+00,  3.77960813e+00],
#        [ 1.00000000e+00,  2.51070324e+00,  6.30363076e+00],
# ...

# %% [markdown]
# ___
#
# # Now Use Regression
#
# ___

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(X_Train_poly, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test_poly)

# %%
print("Predicted  :", y_pred[:5].round(2))
print("Actual     :", y_test[:5])
# Out:
# Predicted  : [[10.97]
#  [ 1.34]
#  [ 8.  ]
#  [ 1.27]
#  [ 3.86]]
# Actual     : [[10.81920584]
#  [ 1.13267281]
#  [ 8.06726128]
#  [ 1.15162441]
#  [ 3.6576619 ]]

# %%
from sklearn.metrics import r2_score

# %%
r2_score  = r2_score(y_test, y_pred)

# %%
print("score : ", r2_score)
# see our Accuracy reached 98 %
# Out:
# score :  0.9931346429162197

# %%
model.coef_
# there are tell valus as B0, B1X1 and B2X2
# Out:
# array([[0.        , 1.55747381, 0.51876807]])

# %%
plt.scatter(X_train, model.predict(X_Train_poly)) # best fit line 
plt.scatter(X_train, y_train)

# %% [markdown]
# # NOTE:
#
# >    When we chnage Degree the accuracy also changes.  so Try different Degrees and which ever gives the best accracy keep that

# %% [markdown]
# ___
# # PipeLine
# ___

# %%
from sklearn.pipeline import Pipeline

# %%
def poly_regression_degree(degree):
    
    X_new = np.linspace(-3, 3, 200).reshape(200, 1)

    # Polynomial features
    poly_features = PolynomialFeatures(
        degree=degree,
        include_bias=True
    )

    # Linear model
    model = LinearRegression()

    # Pipeline
    poly_regression = Pipeline([
        ("poly_features", poly_features),
        ("model", model)
    ])

    # Train
    poly_regression.fit(X_train, y_train)

    # Predict
    y_pred_new = poly_regression.predict(X_new)

    # Plot polynomial curve
    plt.plot(
        X_new,
        y_pred_new,
        'r',
        label=f"Degree {degree}"
    )

    # Plot data points
    plt.scatter(X_train, y_train)
    plt.scatter(X_test, y_test)

    plt.legend(loc="upper left")
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.axis([-4, 4, 0, 10])

    plt.show()

# %%
poly_regression_degree(2)

# %%
poly_regression_degree(20)
